# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')
# Out:
# <ipython-input-1-5edeadb82d5d>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.model_selection import GroupShuffleSplit

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import callbacks

spotify = pd.read_csv('spotify.csv')

X = spotify.copy().dropna()
y = X.pop('track_popularity')
artists = X['track_artist']

features_num = ['danceability', 'energy', 'key', 'loudness', 'mode',
                'speechiness', 'acousticness', 'instrumentalness',
                'liveness', 'valence', 'tempo', 'duration_ms']
features_cat = ['playlist_genre']

preprocessor = make_column_transformer(
    (StandardScaler(), features_num),
    (OneHotEncoder(), features_cat),
)

# We'll do a "grouped" split to keep all of an artist's songs in one
# split or the other. This is to help prevent signal leakage.
def group_split(X, y, group, train_size=0.75):
    splitter = GroupShuffleSplit(train_size=train_size)
    train, test = next(splitter.split(X, y, groups=group))
    return (X.iloc[train], X.iloc[test], y.iloc[train], y.iloc[test])

X_train, X_valid, y_train, y_valid = group_split(X, y, artists)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)
y_train = y_train / 100 # popularity is on a scale 0-100, so this rescales to 0-1.
y_valid = y_valid / 100

input_shape = [X_train.shape[1]]
print("Input shape: {}".format(input_shape))
# Out:
# Input shape: [18]

# %%
model = keras.Sequential([
    layers.Dense(1, input_shape=input_shape),
])
model.compile(
    optimizer='adam',
    loss='mae',
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=100,
    verbose=0, # suppress output since we'll plot the curves
)
history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()));
# Out:
# Minimum Validation Loss: 0.1980

# %%
# Start the plot at epoch 10
history_df.loc[10:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()));
# Out:
# Minimum Validation Loss: 0.1980

# %%
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=input_shape),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
])
model.compile(
    optimizer='adam',
    loss='mae',
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=100,
)
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()));
# Out:
# Epoch 1/100
# 49/49 [==============================] - 1s 9ms/step - loss: 0.2328 - val_loss: 0.2090
# Epoch 2/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2028 - val_loss: 0.2007
# Epoch 3/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1985 - val_loss: 0.2004
# Epoch 4/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1959 - val_loss: 0.2023
# Epoch 5/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1961 - val_loss: 0.2024
# Epoch 6/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.1942 - val_loss: 0.1991
# Epoch 7/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1910 - val_loss: 0.1990
# Epoch 8/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1915 - val_loss: 0.1990
# Epoch 9/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1899 - val_loss: 0.1973
# Epoch 10/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1894 - val_loss: 0.1984
# Epoch 11/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1892 - val_loss: 0.1990
# Epoch 12/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1900 - val_loss: 0.1978
# Epoch 13/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.1866 - val_loss: 0.1973
# Epoch 14/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1854 - val_loss: 0.1973
# Epoch 15/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1859 - val_loss: 0.1983
# Epoch 16/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1849 - val_loss: 0.1995
# Epoch 17/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1871 - val_loss: 0.1981
# Epoch 18/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1840 - val_loss: 0.1971
# Epoch 19/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1841 - val_loss: 0.1965
# Epoch 20/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1829 - val_loss: 0.1967
# Epoch 21/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.1835 - val_loss: 0.1995
# Epoch 22/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1842 - val_loss: 0.1971
# Epoch 23/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1852 - val_loss: 0.1985
# Epoch 24/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1840 - val_loss: 0.1977
# Epoch 25/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1820 - val_loss: 0.2007
# Epoch 26/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1839 - val_loss: 0.1971
# Epoch 27/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1819 - val_loss: 0.1978
# Epoch 28/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1811 - val_loss: 0.1994
# Epoch 29/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1805 - val_loss: 0.1994
# Epoch 30/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1806 - val_loss: 0.2027
# Epoch 31/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1843 - val_loss: 0.1982
# Epoch 32/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1821 - val_loss: 0.1975
# Epoch 33/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1790 - val_loss: 0.1976
# Epoch 34/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1797 - val_loss: 0.1986
# Epoch 35/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1797 - val_loss: 0.1971
# Epoch 36/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.1781 - val_loss: 0.1982
# Epoch 37/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1789 - val_loss: 0.1980
# Epoch 38/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1792 - val_loss: 0.1972
# Epoch 39/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1778 - val_loss: 0.1988
# Epoch 40/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1809 - val_loss: 0.1977
# Epoch 41/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1783 - val_loss: 0.1973
# Epoch 42/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1775 - val_loss: 0.1977
# Epoch 43/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1773 - val_loss: 0.1986
# Epoch 44/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.1774 - val_loss: 0.1992
# Epoch 45/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1772 - val_loss: 0.1980
# Epoch 46/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1753 - val_loss: 0.1986
# Epoch 47/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1757 - val_loss: 0.1994
# Epoch 48/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1749 - val_loss: 0.1992
# Epoch 49/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1748 - val_loss: 0.2006
# Epoch 50/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1792 - val_loss: 0.1997
# Epoch 51/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1758 - val_loss: 0.2035
# Epoch 52/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.1770 - val_loss: 0.1997
# Epoch 53/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1763 - val_loss: 0.1995
# Epoch 54/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1766 - val_loss: 0.1985
# Epoch 55/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1758 - val_loss: 0.1994
# Epoch 56/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1746 - val_loss: 0.1995
# Epoch 57/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1735 - val_loss: 0.2036
# Epoch 58/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1783 - val_loss: 0.2018
# Epoch 59/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1734 - val_loss: 0.1995
# Epoch 60/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1723 - val_loss: 0.2005
# Epoch 61/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1722 - val_loss: 0.1999
# Epoch 62/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1718 - val_loss: 0.1999
# Epoch 63/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1720 - val_loss: 0.2018
# Epoch 64/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1746 - val_loss: 0.2000
# Epoch 65/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1729 - val_loss: 0.2015
# Epoch 66/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1732 - val_loss: 0.2029
# Epoch 67/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1727 - val_loss: 0.2022
# Epoch 68/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1717 - val_loss: 0.2017
# Epoch 69/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1711 - val_loss: 0.2018
# Epoch 70/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1727 - val_loss: 0.2011
# Epoch 71/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1705 - val_loss: 0.2122
# Epoch 72/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1746 - val_loss: 0.2023
# Epoch 73/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1701 - val_loss: 0.2020
# Epoch 74/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1719 - val_loss: 0.2015
# Epoch 75/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1699 - val_loss: 0.2017
# Epoch 76/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1699 - val_loss: 0.2047
# Epoch 77/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1708 - val_loss: 0.2014
# Epoch 78/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.1685 - val_loss: 0.2026
# Epoch 79/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1686 - val_loss: 0.2045
# Epoch 80/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1721 - val_loss: 0.2029
# Epoch 81/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1674 - val_loss: 0.2032
# Epoch 82/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1712 - val_loss: 0.2025
# Epoch 83/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1686 - val_loss: 0.2025
# Epoch 84/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1689 - val_loss: 0.2042
# Epoch 85/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1726 - val_loss: 0.2059
# Epoch 86/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1690 - val_loss: 0.2023
# Epoch 87/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1673 - val_loss: 0.2057
# Epoch 88/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1688 - val_loss: 0.2035
# Epoch 89/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.1677 - val_loss: 0.2040
# Epoch 90/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1670 - val_loss: 0.2048
# Epoch 91/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1708 - val_loss: 0.2035
# Epoch 92/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1666 - val_loss: 0.2033
# Epoch 93/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.1663 - val_loss: 0.2050
# Epoch 94/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.1672 - val_loss: 0.2041
# Epoch 95/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.1656 - val_loss: 0.2059
# Epoch 96/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1660 - val_loss: 0.2041
# Epoch 97/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1656 - val_loss: 0.2043
# Epoch 98/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.1646 - val_loss: 0.2052
# Epoch 99/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.1637 - val_loss: 0.2057
# Epoch 100/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1642 - val_loss: 0.2055
# Minimum Validation Loss: 0.1965
